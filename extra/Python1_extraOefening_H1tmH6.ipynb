# %% [markdown]
# # Extra oefeningen Python Onderwerpen 1 t/m 6

# %% [markdown]
# <h3 id="opgaveSamen1">Samenvattingsopgave 1: keuzes</h3>
#
# a) Breid de code hieronder uit zodat de gebruiker wordt gevraagd hun cijfer voor informatica in te voeren.
#
# b) Als:
# - de cijfer een 5,5 of hoger is, print dan 'Voldodende'
# - anders print 'Onvoldoende'
#
# c) Als ze een onvoldfoende hebben en:
# - een 'j' hebben ingevoerd bij de vraag of ze hun best willen doen, print dan "je gaat het halen".
# - anders print "jammer"

# %%
print("Ben je bereid je best te doen? Typ 'j' of 'n'")
ingevoerde_best = input()

print("Wat sta je nu voor informatica?")

# %% [markdown]
# <p>Bekijk <a href="https://rweeda.github.io/PythonIA/docs/HerP1_oplossingen.html#opgaveSamen1" target="_blank">hier</a> een voorbeeld uitwerking.</p>

# %% [markdown]
# <h3 id="opgaveSamen2">Samenvattingsopgave 2: cijfers</h3>

# %% [markdown]
# a) Schrijf een functie <code>bepaalGehaald</code>. De functie krijgt een <code>cijfer</code> binnen.
# Als de cijfer een 5,5 of hoger is, geef dan <code>True</code> terug, anders geef je <code>False</code> terug.
#
#
# b) Haal de onderste twee regels code uit commentaar om te testen of je functie werkt. Test met verschillende waarden: een voldoende, een onvoldoende en een 5,5 (net voldoende)

# %%
### FUNCTIE DEFINITIES  #####







### HOOFDPROGRAMMA #####

#is_gehaald = bepaalGehaald( 6 )  #roep functie aan en sla het antwoord op in de variabele 'is_gehaald'
#print(is-gehaald)

# %% [markdown]
# <p>Bekijk <a href="https://rweeda.github.io/PythonIA/docs/HerP1_oplossingen.html#opgaveSamen2" target="_blank">hier</a> een voorbeeld uitwerking.</p>

# %% [markdown]
# <h3 id="opgaveSamen3">Samenvattingsopgave 3: oefen met functies</h3>

# %% [markdown]
# Hieronder staat code voor de functie <code>bepaalSom</code>. Die krijgt twee getallen binnen, telt ze bij elkaar op en levert het resultaat op.
#
# Volg de volgende stappen:
# 1) Geef op regel 2 aan welke parameters <code>bepaalSom</code> binnen krijgt.
# 2) Op regel 3 tel je die bij elkaar op
# 3) Op regel 4 lever je het antwoord op
#
# 4) Bedenk wat er gebeurt op regels 8 en 9?
# 5) Vraag op regel 10 de invoer van het tweede getal
# 6) Zet op regel 11 de invoer om in een getal
# 7) Op regel 13: Roep de functie <code>bepaalSom</code> aan met de juiste parameters (de getallen die je meegeeft)
# 8) Op regel 14 print je het uiteindelijke som

# %%
##### FUNCTIE DEFINITIES ######
def bepaalSom( ....  ,  ..... ):  # welke informtie krijgt de functie binnen?
  antwoord = ...                  # tel hier die getallen bij elkaar op
  ......                          # return hier het antwoord


#### HOOFDPROGRAMMA #####
invoer1 = input ("Geef een getal")
getal1 = int (invoer1)
invoer2 =                       # vraag hier om een tweede getal
                                # verander invoer2 in een getal en sla dat op in variabele getal2

som = bepaalSom( ..... )        # Welke twee getallen geef je mee?
print("De som is", ..... )      # welk variabele druk je af?

# %% [markdown]
# <p>Bekijk <a href="https://rweeda.github.io/PythonIA/docs/HerP1_oplossingen.html#opgaveSamen3" target="_blank">hier</a> een voorbeeld uitwerking.</p>

# %% [markdown]
# <h3 id="opgaveSamen4">Samenvattingsopgave 4: nu zelf oefenen met functies</h3>

# %% [markdown]
# Schrijf een functie die de oppervlakte van een rechthoek berekent en oplevert.
#
# De oppervlakte bereken je door lengte * breedte.
#
# In je hoofdprogramma roep je de functie aan, sla je het antwoord op in de variabele <code>oppervlakte</code>.
# In de regel daarna print je <code>oppervlakte</code>

# %%
### FUNCTIE DEFINITIES #####
# schrijf hier je definitie





### HOOFDPROGAMMA ####
zijde1 = 2
zijde2 = 4
# hier roep je straks je functie aan





#print(oppervlakte)

# %% [markdown]
# <p>Bekijk <a href="https://rweeda.github.io/PythonIA/docs/HerP1_oplossingen.html#opgaveSamen4" target="_blank">hier</a> een voorbeeld uitwerking.</p>
