# %% [markdown]
# ## Onderwerp 16: Afsluitende opdrachten
#
# <p>Met de volgende afsluitende opdrachten kun je kijken hoe goed je de stof beheerst. Controleer steeds je eigen oplossing met de voorbeelduitwerking.</p>
# <table>
#   <tr>
#     <td style="text-align: left; vertical-align: top;" width=50%>
#       <p>Voor de volgende afsluitende opdrachten maken we steeds gebruik van de dictionary <code>profielen</code>. Deze dictionary bevat gegevens over verschillende gebruikers van een social media-platform. Elke gebruikersnaam (zoals "skydiver_22" of "techie99") is een sleutel in de dictionary. De bijbehorende waarde is een geneste dictionary met vier onderdelen:</p>
#       <ul>
#         <li><i>bio</i>: een korte beschrijving van de gebruiker (string),</li>
#         <li><i>volgers</i>: het aantal volgers van de gebruiker (integer),</li>
#         <li><i>posts</i>: het aantal berichten dat de gebruiker heeft geplaatst (integer),</li>
#         <li><i>interesses</i>: een lijst van onderwerpen waarin de gebruiker geïnteresseerd is (list van strings).</li>
#       </ul>
#     </td>
#     <td style="vertical-align: top;">
#       <img src="https://raw.githubusercontent.com/rweeda/PythonIA/main/img/dictionary_profielen.png" >
#     </td>
#   </tr>
# </table>

# %%
profielen = {
    "skydiver_22": {
        "bio": "Ik hou van katten en gamen",
        "volgers": 134,
        "posts": 47,
        "interesses": ["dieren", "games", "fotografie"]
    },
    "dancequeen": {
        "bio": "Altijd aan het dansen",
        "volgers": 245,
        "posts": 82,
        "interesses": ["muziek", "games", "vloggen"]
    },
    "bookworm": {
        "bio": "Ik lees elke dag",
        "volgers": 98,
        "posts": 133,
        "interesses": ["boeken", "schrijven", "fotografie"]
    },
    "techie99": {
        "bio": "Fan van programmeren en robots",
        "volgers": 187,
        "posts": 59,
        "interesses": ["programmeren", "AI", "games"]
    }
}

# %% [markdown]
# ### Afsluitende Opdracht 16.16.1 Profielen met meer dan 100 volgers
# <p>Schrijf een programma dat print welke profielen meer dan 100 volgers hebben.</p>
#
# <p>Verwachte uitvoer:<br>
# <i>Profiel skydiver_22 heeft meer dan 100 volgers<br>
# Profiel dancequeen heeft meer dan 100 volgers<br>
# Profiel techie99 heeft meer dan 100 volgers</i></p>

# %%
profielen = {
    "skydiver_22": {
        "bio": "Ik hou van katten en gamen",
        "volgers": 134,
        "posts": 47,
        "interesses": ["dieren", "games", "fotografie"]
    },
    "dancequeen": {
        "bio": "Altijd aan het dansen",
        "volgers": 245,
        "posts": 82,
        "interesses": ["muziek", "games", "vloggen"]
    },
    "bookworm": {
        "bio": "Ik lees elke dag",
        "volgers": 98,
        "posts": 133,
        "interesses": ["boeken", "schrijven", "fotografie"]
    },
    "techie99": {
        "bio": "Fan van programmeren en robots",
        "volgers": 187,
        "posts": 59,
        "interesses": ["programmeren", "AI", "games"]
    }
}

# %% [markdown]
# ### Afsluitende Opdracht 16.16.2 Aantal profielen met games als interesse
#
# <p>Schrijf een functie die de dictionary doorloopt en een lijst oplevert van alle profielen die 'games' als interesse hebben.</p>
#
# <p>De verwachte invoer is:<br>
# <i>['skydiver_22', 'dancequeen', 'techie99']</i></p>

# %%
profielen = {
    "skydiver_22": {
        "bio": "Ik hou van katten en gamen",
        "volgers": 134,
        "posts": 47,
        "interesses": ["dieren", "games", "fotografie"]
    },
    "dancequeen": {
        "bio": "Altijd aan het dansen",
        "volgers": 245,
        "posts": 82,
        "interesses": ["muziek", "games", "vloggen"]
    },
    "bookworm": {
        "bio": "Ik lees elke dag",
        "volgers": 98,
        "posts": 133,
        "interesses": ["boeken", "schrijven", "fotografie"]
    },
    "techie99": {
        "bio": "Fan van programmeren en robots",
        "volgers": 187,
        "posts": 59,
        "interesses": ["programmeren", "AI", "games"]
    }
}

# %% [markdown]
# ### Afsluitende Opdracht 16.16.3 Totaal aantal volgers
#
# <p>Bepaal het totale aantal volgers van alle profielen samen en print dit.</p>
# <p>De verwachte uitvoer:<br>
# <i>Totaal aantal volgers: 664</i></p>

# %%
profielen = {
    "skydiver_22": {
        "bio": "Ik hou van katten en gamen",
        "volgers": 134,
        "posts": 47,
        "interesses": ["dieren", "games", "fotografie"]
    },
    "dancequeen": {
        "bio": "Altijd aan het dansen",
        "volgers": 245,
        "posts": 82,
        "interesses": ["muziek", "games", "vloggen"]
    },
    "bookworm": {
        "bio": "Ik lees elke dag",
        "volgers": 98,
        "posts": 133,
        "interesses": ["boeken", "schrijven", "fotografie"]
    },
    "techie99": {
        "bio": "Fan van programmeren en robots",
        "volgers": 187,
        "posts": 59,
        "interesses": ["programmeren", "AI", "games"]
    }
}

# %% [markdown]
# ### Afsluitende Opdracht 16.16.4 Gemiddeld aantal posts (aantal posts/aantal profielen)
#
#
# <p>Schrijf een functie om het <b>gemiddeld aantal posts</b> per profiel uit te rekenen. Roep de functie aan en print het gemiddelde.</p>
# <p>Tip: Deel het totaal aantal posts door het aantal profielen.</p>
#
# <p>Verwachte uitvoer:</b>
# <i>Gemiddeld aantal posts: 80.25</i></p>

# %%
profielen = {
    "skydiver_22": {
        "bio": "Ik hou van katten en gamen",
        "volgers": 134,
        "posts": 47,
        "interesses": ["dieren", "games", "fotografie"]
    },
    "dancequeen": {
        "bio": "Altijd aan het dansen",
        "volgers": 245,
        "posts": 82,
        "interesses": ["muziek", "games", "vloggen"]
    },
    "bookworm": {
        "bio": "Ik lees elke dag",
        "volgers": 98,
        "posts": 133,
        "interesses": ["boeken", "schrijven", "fotografie"]
    },
    "techie99": {
        "bio": "Fan van programmeren en robots",
        "volgers": 187,
        "posts": 59,
        "interesses": ["programmeren", "AI", "games"]
    }
}

# %% [markdown]
# ### Afsluitende Opdracht 16.16.5 Minder dan 60 posts filteren
#
# <p>Filter alle profielen die minder dan 60 posts hebben geplaatst. Zet de overgebleven profiele in een lijst en print die.</p>
#
# <p>De verwachte uitvoer is:<br>
# <i>Overgebleven profielen: ['dancequeen', 'bookworm']</i></p>

# %%
profielen = {
    "skydiver_22": {
        "bio": "Ik hou van katten en gamen",
        "volgers": 134,
        "posts": 47,
        "interesses": ["dieren", "games", "fotografie"]
    },
    "dancequeen": {
        "bio": "Altijd aan het dansen",
        "volgers": 245,
        "posts": 82,
        "interesses": ["muziek", "games", "vloggen"]
    },
    "bookworm": {
        "bio": "Ik lees elke dag",
        "volgers": 98,
        "posts": 133,
        "interesses": ["boeken", "schrijven", "fotografie"]
    },
    "techie99": {
        "bio": "Fan van programmeren en robots",
        "volgers": 187,
        "posts": 59,
        "interesses": ["programmeren", "AI", "games"]
    }
}

# %% [markdown]
# ### Afsluitende Opdracht 16.16.6 Nieuwe profiel toevoegen
#
# <p>Schrijf een functie die een gebruiker vraagt om een profielnaam, een bio en interesses.
# Als het profiel nog niet bestaat in de dictionary, voeg het dan toe met 0 volgers en 0 posts.
# Als het profiel al bestaat, toon dan een foutmelding.</p>
#
# <p>Voorbeeld verwachte uitvoer:<br>
# <i>Nieuw profiel catlover toegevoegd.</i><br>
# of<br>
# <i>Profiel dancequeen bestaat al!</i></p>

# %%
profielen = {
    "skydiver_22": {
        "bio": "Ik hou van katten en gamen",
        "volgers": 134,
        "posts": 47,
        "interesses": ["dieren", "games", "fotografie"]
    },
    "dancequeen": {
        "bio": "Altijd aan het dansen",
        "volgers": 245,
        "posts": 82,
        "interesses": ["muziek", "games", "vloggen"]
    },
    "bookworm": {
        "bio": "Ik lees elke dag",
        "volgers": 98,
        "posts": 133,
        "interesses": ["boeken", "schrijven", "fotografie"]
    },
    "techie99": {
        "bio": "Fan van programmeren en robots",
        "volgers": 187,
        "posts": 59,
        "interesses": ["programmeren", "AI", "games"]
    }
}

# %% [markdown]
# ### Afsluitende Opdracht 16.16.7 Nieuwe volger voor iedereen
#
# <p>Verhoog het aantal volgers van elk profiel in de dictionary met 1. Print daarna de inhoud van de dictionary</p>
# <p>Verwachte uitvoer:<br>
# <i>Volgers bijgewerkt: {'skydiver_22': {'bio': 'Ik hou van katten en gamen', 'volgers': 135, 'posts': 47, 'interesses': ['dieren', 'games', 'fotografie']}, 'dancequeen': {'bio': 'Altijd aan het dansen', 'volgers': 246, 'posts': 82, 'interesses': ['muziek', 'games', 'vloggen']}, 'bookworm': {'bio': 'Ik lees elke dag', 'volgers': 99, 'posts': 133, 'interesses': ['boeken', 'schrijven', 'fotografie']}, 'techie99': {'bio': 'Fan van programmeren en robots', 'volgers': 188, 'posts': 59, 'interesses': ['programmeren', 'AI', 'games']}}</i></p>

# %%
profielen = {
    "skydiver_22": {
        "bio": "Ik hou van katten en gamen",
        "volgers": 134,
        "posts": 47,
        "interesses": ["dieren", "games", "fotografie"]
    },
    "dancequeen": {
        "bio": "Altijd aan het dansen",
        "volgers": 245,
        "posts": 82,
        "interesses": ["muziek", "games", "vloggen"]
    },
    "bookworm": {
        "bio": "Ik lees elke dag",
        "volgers": 98,
        "posts": 133,
        "interesses": ["boeken", "schrijven", "fotografie"]
    },
    "techie99": {
        "bio": "Fan van programmeren en robots",
        "volgers": 187,
        "posts": 59,
        "interesses": ["programmeren", "AI", "games"]
    }
}

# %% [markdown]
# ### Afsluitende Opdracht 16.16.8 Gezamenlijke interesses
#
# <p>Vraag de gebruiker om een interesse en toon alle profielen die dezelfde interesse hebben.</p>
#
# <p>Voorbeeld verwachte uitvoer:<br>
# <i>skydiver_22 heeft ook de interesse games<br>
# dancequeen heeft ook de interesse games<br>
# techie99 heeft ook de interesse games</i></p>

# %%
profielen = {
    "skydiver_22": {
        "bio": "Ik hou van katten en gamen",
        "volgers": 134,
        "posts": 47,
        "interesses": ["dieren", "games", "fotografie"]
    },
    "dancequeen": {
        "bio": "Altijd aan het dansen",
        "volgers": 245,
        "posts": 82,
        "interesses": ["muziek", "games", "vloggen"]
    },
    "bookworm": {
        "bio": "Ik lees elke dag",
        "volgers": 98,
        "posts": 133,
        "interesses": ["boeken", "schrijven", "fotografie"]
    },
    "techie99": {
        "bio": "Fan van programmeren en robots",
        "volgers": 187,
        "posts": 59,
        "interesses": ["programmeren", "AI", "games"]
    }
}

# %% [markdown]
# ### Afsluitende Opdracht 16.16.9 Lijst van interesses
# <p>Maak een lijst van alle interesses uit de profielen, waarbij elke interesse maar één keer voorkomt. Gebruik hiervoor de <i>filter plan</i>, doorloop de dictionary en voeg telkens een interesse toe aan de lijst als die er nog niet in voorkomt.
# Druk na afloop de lijst af.</p>
#
# <p>De verwachte uitvoer is:<br>
# <i>Alle unieke interesses: ['dieren', 'games', 'fotografie', 'muziek', 'vloggen', 'boeken', 'schrijven', 'programmeren', 'AI']</i></p>

# %%
profielen = {
    "skydiver_22": {
        "bio": "Ik hou van katten en gamen",
        "volgers": 134,
        "posts": 47,
        "interesses": ["dieren", "games", "fotografie"]
    },
    "dancequeen": {
        "bio": "Altijd aan het dansen",
        "volgers": 245,
        "posts": 82,
        "interesses": ["muziek", "games", "vloggen"]
    },
    "bookworm": {
        "bio": "Ik lees elke dag",
        "volgers": 98,
        "posts": 133,
        "interesses": ["boeken", "schrijven", "fotografie"]
    },
    "techie99": {
        "bio": "Fan van programmeren en robots",
        "volgers": 187,
        "posts": 59,
        "interesses": ["programmeren", "AI", "games"]
    }
}

# %% [markdown]
# ### Afsluitende Opdracht 16.16.10 Populaire fotografieprofielen vinden
#
# <p>Schrijf een programma dat een lijst afdrukt van gebruikers die meer dan 100 volgers hebben én geïnteresseerd zijn in fotografie.<br>
# Gebruik de dictionary profielen hieronder.</p>
#
# <p>De verwachte uitvoer is:<br>
# <i>Populaire fotografieprofielen: ['skydiver_22']</i></p>

# %%
profielen = { 
    "skydiver_22": {
        "bio": "Ik hou van katten en gamen",
        "volgers": 134,
        "posts": 47,
        "interesses": ["dieren", "games", "fotografie"]
    },
    "dancequeen": {
        "bio": "Altijd aan het dansen",
        "volgers": 245,
        "posts": 82,
        "interesses": ["muziek", "games", "vloggen"]
    },
    "bookworm": {
        "bio": "Ik lees elke dag",
        "volgers": 98,
        "posts": 133,
        "interesses": ["boeken", "schrijven", "fotografie"]
    },
    "techie99": {
        "bio": "Fan van programmeren en robots",
        "volgers": 187,
        "posts": 59,
        "interesses": ["programmeren", "AI", "games"]
    }
}

# %% [markdown]
# ### Afsluitende Opdracht 16.16.11 Wie is er dol op programmeren of deelt veel?
# <p>Schrijf een programma dat alle bio's afdrukt van gebruikers die:
# <ul>
# <li>óf "programmeren" als interesse hebben,
# <li>óf meer posts dan volgers hebben.
# </ul>
# Zorg dat de bio’s netjes met print() worden afgedrukt.</p>
#
# <p>De verwachte uitvoer is:<br>
# <i>Ik lees elke dag<br>
# Fan van programmeren en robots</i></p>

# %%
profielen = {
    "skydiver_22": {
        "bio": "Ik hou van katten en gamen",
        "volgers": 134,
        "posts": 47,
        "interesses": ["dieren", "games", "fotografie"]
    },
    "dancequeen": {
        "bio": "Altijd aan het dansen",
        "volgers": 245,
        "posts": 82,
        "interesses": ["muziek", "games", "vloggen"]
    },
    "bookworm": {
        "bio": "Ik lees elke dag",
        "volgers": 98,
        "posts": 133,
        "interesses": ["boeken", "schrijven", "fotografie"]
    },
    "techie99": {
        "bio": "Fan van programmeren en robots",
        "volgers": 187,
        "posts": 59,
        "interesses": ["programmeren", "AI", "games"]
    }
}

# %% [markdown]
# ### Afsluitende Opdracht 16.16.12 Verwijder spam-profielen
# <p>Verwijder alle profielen uit de dictionary die meer dan 10.000 posts hebben (spam).<br>
# Druk daarna de aangepaste dictionary af met print().</p>
# <p>Maak eerst een lege dictionary.
# Doorloop alle profielen en voeg de <b>niet</b>-spam-profielen toe aan de lege dictionary.</p>
#
# <!--del (kan niet in for-loop) - eerst de keys bepalen, en dan nieuwe forloop--- denken we-->
#
#
# <p>De verwachte uitvoer is:<br>
# <i>Profielen zonder spam:
# {'skydiver_22': {'bio': 'Ik hou van katten en gamen', 'volgers': 134, 'posts': 47, 'interesses': ['dieren', 'games', 'fotografie']}, 'dancequeen': {'bio': 'Altijd aan het dansen', 'volgers': 245, 'posts': 82, 'interesses': ['muziek', 'games', 'vloggen']}, 'bookworm': {'bio': 'Ik lees elke dag', 'volgers': 98, 'posts': 133, 'interesses': ['boeken', 'schrijven', 'fotografie']}, 'techie99': {'bio': 'Fan van programmeren en robots', 'volgers': 187, 'posts': 59, 'interesses': ['programmeren', 'AI', 'games']}}
# </i></p>

# %%
profielen = { 
    "skydiver_22": {
        "bio": "Ik hou van katten en gamen",
        "volgers": 134,
        "posts": 47,
        "interesses": ["dieren", "games", "fotografie"]
    },
    "dancequeen": {
        "bio": "Altijd aan het dansen",
        "volgers": 245,
        "posts": 82,
        "interesses": ["muziek", "games", "vloggen"]
    },
    "bookworm": {
        "bio": "Ik lees elke dag",
        "volgers": 98,
        "posts": 133,
        "interesses": ["boeken", "schrijven", "fotografie"]
    },
    "techie99": {
        "bio": "Fan van programmeren en robots",
        "volgers": 187,
        "posts": 59,
        "interesses": ["programmeren", "AI", "games"]
    },
    "spam_king": {
        "bio": "Volg mij voor 10.000 updates per dag!",
        "volgers": 5,
        "posts": 25000,
        "interesses": ["reclame", "spam", "massaposts"]
    }
}

# %% [markdown]
# ### Afsluitende opdracht 16.16.3 Profielen opslaan en laden met JSON
# Sla de gegevens van de profielen dictionary in een JSON-bestand en lees deze daarna weer in.
#
# <ol style="list-style-type: lower-alpha">
# <li>Sla de dictionary <code>profielen</code> op in een JSON-bestand met de naam <code>profielen.json</code>;</li>
# <li>Sluit het bestand netjes af;</li>
# <li>Open het bestand opnieuw en laad de data in een nieuwe dictionary;</li>
# <li>Print de nieuwe dictionary op het scherm.</li>
# </ol>
#
#
# <p>De verwachte uitvoer is (ingekort):<br>
# <i>{'skydiver_22': {'bio': 'Ik hou van katten en gamen', 'volgers': 134, 'posts': 47, 'interesses': ['dieren', 'games', 'fotografie']}, ...}
# </i></p>

# %%
import json

profielen = {
    "skydiver_22": {
        "bio": "Ik hou van katten en gamen",
        "volgers": 134,
        "posts": 47,
        "interesses": ["dieren", "games", "fotografie"]
    },
    "dancequeen": {
        "bio": "Altijd aan het dansen",
        "volgers": 245,
        "posts": 82,
        "interesses": ["muziek", "games", "vloggen"]
    },
    "bookworm": {
        "bio": "Ik lees elke dag",
        "volgers": 98,
        "posts": 133,
        "interesses": ["boeken", "schrijven", "fotografie"]
    },
    "techie99": {
        "bio": "Fan van programmeren en robots",
        "volgers": 187,
        "posts": 59,
        "interesses": ["programmeren", "AI", "games"]
    }
}
